# %% [markdown]
# # A comparative study on different Machine Learning algorithms using scikit-learn.
#
#
# ***
# **Developed by: M.Safaei**
# [Likedin](https://www.linkedin.com/in/mattsafaei/)
# ***
#
# Table of contents:
# 1. Initial data preprocessing
# 2. Normal vs actual distribution of feature components for each species
# 3. Machine Learning models optimization and evaluation. I use `GridSearchCV` for optimization of hyperparameters.
# 4. Dimensionality reduction using Principal Component Analysis (PCA) and TruncatedSVD
#     4.1. Prediction of the species of the test sample using these algorithms
# 5. Spliting the data to train, test and validation segments
# 6. Optimizing the hyperparameters
# 7. Speed and Score comparison for most accurare of each algorithm
# 8. Correlation map function definition
# 9. Metrics
#     1. Precision score
#         1. Averaged
#         3. Individual
#     2. Accuracy score
#     3. Recall score
# 10. Classification report
# 11. Confusion matrix for all models
# 12. Normalized confusion matrix for all models
#
#
# ***
# **Machine Learning Models Evaluated**
# 1. Logistic Regression
#
# - Decision Tree
#
# - K-Neighbors
#
# - Linear Discriminant Analysis
# - Gaussian Naive Bayes
#
# - Support Vector Machine
#
# - Random Forest
#
# - Neural Network (Multi-Layer Perceptron)
# ***

# %%
# to suspend the future warnings that can be troublesome specially for MLP
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
# to get around some of the version incompatibily
from __future__ import absolute_import 
from __future__ import division 
from __future__ import print_function

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# importing packages needed for this notebook

from time import time

import pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix


from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPRegressor, MLPClassifier

from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib.patches as mpatches


from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

from sklearn.utils.multiclass import unique_labels


from sklearn import model_selection
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
# Loading the iris dataset directly from seaborn
df = sns.load_dataset("iris")
df.head(6)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
# names of the lables and features
# df.columns

# %%
# descriptions for the features
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# let's see if there is anything missing. 
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# see if the distributin of labels is normal or skewed

df['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
sns.countplot(data=df, x='species',hue='species')

# %% [markdown]
# ## Boxplots
# ### For instance, we see that setosa's petal width and length are smallest among other species
#
# It helps us to see between 25% and 75% (both end of the squares) and also recognize severity of extreme outliers (points beyond the lower and higher extreme)

# %%
colors = ["#FF0000", "#00FF00","#0000FF"]

f, axes = plt.subplots(ncols=4, figsize=(20,4))

sns.boxplot(x="species", y="sepal_length", data=df, palette=colors, ax=axes[0])
axes[0].set_title('species vs sepal_length')

sns.boxplot(x="species", y="sepal_width", data=df, palette=colors, ax=axes[1])
axes[1].set_title('species vs sepal_width')

sns.boxplot(x="species", y="petal_length", data=df, palette=colors, ax=axes[2])
axes[2].set_title('species vs petal_length')

sns.boxplot(x="species", y="petal_width", data=df, palette=colors, ax=axes[3])
axes[3].set_title('species vs petal_width')

plt.show()

# %%
# a simple check on the actual numbers
print(df[df['species']=='setosa']['sepal_length'].mean(),
df[df['species']=='virginica']['sepal_length'].mean(),
df[df['species']=='versicolor']['sepal_length'].mean()
     )
# Out:
# 5.005999999999999 6.587999999999998 5.936

# %% [markdown]
# # Normal vs actual distribution of feature components for each species

# %%
from scipy.stats import norm

f, ax = plt.subplots(3,1, figsize=(20, 10),sharex=True)


distrubution_1 = df['sepal_length'].loc[df['species'] == 'setosa'].values
distrubution_2 = df['sepal_width'].loc[df['species'] == 'setosa'].values
distrubution_3 = df['petal_length'].loc[df['species'] == 'setosa'].values
distrubution_4 = df['petal_width'].loc[df['species'] == 'setosa'].values
sns.distplot(distrubution_1, fit=norm,ax= ax[0], color='#ffff00', label ='sepal_length' )
sns.distplot(distrubution_2, fit=norm, ax= ax[0],color='#00FB00', label ='sepal_width')
sns.distplot(distrubution_3, fit=norm, ax= ax[0],color='#0000FB', label ='petal_length')
sns.distplot(distrubution_4, fit=norm, ax= ax[0],color='#FF0000', label ='petal_width')

ax[0].set_title('setosa', fontsize=14)
ax[0].legend()


distrubution_1 = df['sepal_length'].loc[df['species'] == 'virginica'].values
distrubution_2 = df['sepal_width'].loc[df['species'] == 'virginica'].values
distrubution_3 = df['petal_length'].loc[df['species'] == 'virginica'].values
distrubution_4 = df['petal_width'].loc[df['species'] == 'virginica'].values
sns.distplot(distrubution_1, fit=norm,ax= ax[1], color='#ffff00', label ='sepal_length' )
sns.distplot(distrubution_2, fit=norm, ax= ax[1],color='#00FB00', label ='sepal_width')
sns.distplot(distrubution_3, fit=norm, ax= ax[1],color='#0000FB', label ='petal_length')
sns.distplot(distrubution_4, fit=norm, ax= ax[1],color='#FF0000', label ='petal_width')

ax[1].set_title('virginica', fontsize=14)
ax[1].legend()

distrubution_1 = df['sepal_length'].loc[df['species'] == 'versicolor'].values
distrubution_2 = df['sepal_width'].loc[df['species'] == 'versicolor'].values
distrubution_3 = df['petal_length'].loc[df['species'] == 'versicolor'].values
distrubution_4 = df['petal_width'].loc[df['species'] == 'versicolor'].values
sns.distplot(distrubution_1, fit=norm,ax= ax[2], color='#ffff00', label ='sepal_length' )
sns.distplot(distrubution_2, fit=norm, ax= ax[2],color='#00FB00', label ='sepal_width')
sns.distplot(distrubution_3, fit=norm, ax= ax[2],color='#0000FB', label ='petal_length')
sns.distplot(distrubution_4, fit=norm, ax= ax[2],color='#FF0000', label ='petal_width')

ax[2].set_title('versicolor', fontsize=14)
ax[2].legend()

# %% [markdown]
# # Dimentionality Reduction:
# 1. Pricipal Component Analysis (PCA)
# 2. Truncated SVD
#
# ### The models are evaluated on test data.
# - Both algorithms do a good job in predicting species of the new sample
#
#
# The results shows that the analysis will have a difficult time to distinguish between Versicolor and virginica.

# %%
Features = X_train
Labels = y_train

target_names = ['setosa','versicolor', 'virginica']



fig = plt.figure(figsize=(15, 10))

colors = ['navy', 'turquoise', 'darkorange']

#~~~~~~~~~~~ pca
ax1 = fig.add_subplot(221)


pca = PCA(n_components=2)
Features_r = pca.fit(Features).transform(Features)
# predict
Features_predict_PCA=pca.fit(Features).transform(X_test)


for color, i, target_name in zip(colors, target_names, target_names):
    ax1.scatter(Features_r[Labels == i, 0], Features_r[Labels == i, 1], color=color, alpha=.8, lw=2,label=target_name)
#prediction    
for color, i, target_name in zip(colors, target_names, target_names):
    ax1.scatter(Features_predict_PCA[y_test == i, 0], Features_predict_PCA[y_test == i, 1], color=color, alpha=.8, lw=2,
                label=target_name, marker="^", s=100,facecolors='none')
    
    
ax1.legend(loc='lower center',  scatterpoints=1)
ax1.title.set_text('Dimentionality reduction using Principal Component Analysis\nHollow is prediction over test samples')

#~~~~~~~~~~~ svd
ax2 = fig.add_subplot(222)
svd = TruncatedSVD(n_components=2,n_iter=7)
Features_r = svd.fit(Features).transform(Features)
# predict

Features_predict_SVD=svd.fit(Features).transform(X_test)

for color, i, target_name in zip(colors, target_names, target_names):
    ax2.scatter(Features_r[Labels == i, 0], Features_r[Labels == i, 1], color=color, alpha=.8, lw=lw,label=target_name)
#prediction
for color, i, target_name in zip(colors, target_names, target_names):
    ax2.scatter(Features_predict_SVD[y_test == i, 0], Features_predict_SVD[y_test == i, 1], color=color, alpha=.8, lw=2,
                label=target_name, marker="^", s=100,facecolors='none')    
    
ax2.legend(loc='best', shadow=False, scatterpoints=1)
ax2.title.set_text('Dimentionality reduction using Truncated SVD\nHollow is prediction over test samples')


plt.show()

# %%
# Percentage of variance explained for each components
print('explained variance ratio (first two components) for PCA: {} and SVD {}.'.format(pca.explained_variance_ratio_,
                                                                    svd.explained_variance_ratio_))
# Out:
# explained variance ratio (first two components) for PCA: [0.9410127  0.04014896] and SVD [0.53796034 0.44282133].

# %% [markdown]
# ## The <font color = red>train_test_split </font> can only split in two slices however we desire three segments (train, test and validation)
#
#   - 60% for training
#   - 20% for validation
#   - 20% for testing

# %%
features = df.drop('species', axis=1)
labels = df['species']

# split in two segments
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.4, random_state=51)

# and now split the 40% into half
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=51)

# %% [markdown]
# #### The regularization $\lambda$ and other parameters such as max depth and n_estimator need to be carefully using GridSearchCV fine tuned

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
# ('model name', model(), {'parametrs': {}})
models = []
models.extend([
                (
                'Gradient Boosting Classifier',
                 GradientBoostingClassifier(), 
                 {'parameters' : {
                                'n_estimators': [5, 50, 250, 500],
                                'max_depth': [1, 3, 5, 7, 9],
                                'learning_rate': [0.01, 0.1, 1, 10, 100]
                                 }
                    }
                  ),
                 (
                 'Logistic Regression', 
                  LogisticRegression(),
                  {'parameters': {
                                  'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000,100000]
                                }
                  }
                 ),
                 (
                 'Random Forest Classifier', 
                  RandomForestClassifier(),
                  {'parameters':  {
                    'n_estimators': [5, 50, 250],
                    'max_depth': [2, 4, 8, 16, 32, None]
                                    }
                  }
                 ),
                 (
                 'Support Vector Classifier', 
                  SVC(),
                  {'parameters':  {
                    'kernel': ['linear', 'rbf'],
                    'C': [0.1, 1, 10]
                                    }
                  }
                 ),  
                 (
                 'KNN', 
                  KNeighborsClassifier(),
                  {'parameters':  {
                    'n_neighbors': [3,5],
                    'leaf_size': [10, 30]
                                    }
                  }
                 ),
                 (
                 'Decision Tree Classifier', 
                  DecisionTreeClassifier(),
                  {'parameters':  {
                    'max_depth': [1, 3, 5, 7, 9]
                                    }
                  }
                 ),    


                 (
                 'Neural Network Classifier', 
                  MLPClassifier(),
                  {'parameters':  {
                    'hidden_layer_sizes': [(10,), (50,), (100,)],
                    'activation': ['relu', 'tanh', 'logistic'],
                    'learning_rate': ['constant', 'invscaling', 'adaptive'],
                    'max_iter': [500],
                     'tol': [0.005]
                                    }
                  }
                 ),
                 (
                 'Gaussian Naive Bayes', 
                  GaussianNB(),
                  {'parameters':  {
                                    }
                  }
                 ), 
                 (
                 'Linear Discriminant Analysis', 
                  LinearDiscriminantAnalysis(),
                  {'parameters':  {
                                    }
                  }
                 )
                        ])

# %% [markdown]
# # Optimizing the hyperparameters

# %%
# models=modelsOriginal[4:5]
# models

# %%
fit_model_list = []

# %%
# Run the loop and find the best Hyper Parameters for all models
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
cv_fit = []
parameters = 0
# models = [models[4]]
for i in range(len(models)):
    model_temp = models[i][1]
    
    del parameters
    parameters = models[i][2]['parameters']


    cv = GridSearchCV(model_temp, parameters, cv=5)
    cv_fit.append(cv.fit(X_train, y_train.values.ravel()))
    cv.best_params_
    print('Model Name: {}\n\t Best Parameters: {}'.format(models[i][0],cv.best_params_))
    fit_model_list.append(tuple([models[i][0],tuple([cv.best_params_]),tuple([cv.best_estimator_])]))
# Out:
# Model Name: Gradient Boosting Classifier
# 	 Best Parameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# Model Name: Logistic Regression
# 	 Best Parameters: {'C': 100}
# Model Name: Random Forest Classifier
# 	 Best Parameters: {'max_depth': 2, 'n_estimators': 5}
# Model Name: Support Vector Classifier
# 	 Best Parameters: {'C': 10, 'kernel': 'linear'}
# Model Name: KNN
# 	 Best Parameters: {'leaf_size': 10, 'n_neighbors': 3}
# Model Name: Decision Tree Classifier
# 	 Best Parameters: {'max_depth': 3}
# Model Name: Neural Network Classifier
# 	 Best Parameters: {'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'max_iter': 500, 'tol': 0.005}
# Model Name: Gaussian Naive Bayes
# 	 Best Parameters: {}
# Model Name: Linear Discriminant Analysis
# 	 Best Parameters: {}

# %%
CV_metrix = pd.DataFrame(cv_fit[0].cv_results_)

# %% [markdown]
# # Fitting and predicting Speed and Score Comparison for all algorithms

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(311)



test_score_comparison={}

for i in range(len(models)):
    data_frame = round(pd.DataFrame(cv_fit[i].cv_results_).sort_values('mean_test_score', ascending=False)[0:1]['mean_test_score'].iloc[0],3)
    # pd.DataFrame(cv_fit[i].cv_results_).sort_values('mean_test_score', ascending=False)[0:4][['mean_test_score','mean_fit_time','mean_score_time']]
    test_score_comparison[models[i][0]]= data_frame   
#plot mean test score
plt.rcdefaults()
y = [test_score_comparison[i] for i in test_score_comparison]
x = [i for i in test_score_comparison]

ax1.barh(x, y, align='center')
ax1.invert_yaxis()
ax1.set_xlabel('Mean Test Score')
ax1.set_title('Prediction Score on Test Samples')
plt.xlim([0.85,1])

ax2 = fig.add_subplot(313)
test_score_comparison={}


for i in range(len(models)):
    data_frame = round(pd.DataFrame(cv_fit[i].cv_results_).sort_values('mean_test_score', ascending=False)[0:1]['mean_score_time'].iloc[0],3)
    test_score_comparison[models[i][0]]= data_frame   
#plot mean test score
plt.rcdefaults()
y = [test_score_comparison[i] for i in test_score_comparison]
x = [i for i in test_score_comparison]

ax2.barh(x, y, align='center')
ax2.invert_yaxis()
ax2.set_xlabel('Mean Score Time')
ax2.set_title('Time To Predict Test Samples (most accurate of each model)')
# plt.xlim([0,0.0015])



ax3 = fig.add_subplot(312)
test_score_comparison={}

for i in range(len(models)):
    data_frame = round(pd.DataFrame(cv_fit[i].cv_results_).sort_values('mean_test_score', ascending=False)[0:1]['mean_fit_time'].iloc[0],3)
    test_score_comparison[models[i][0]]= data_frame   
#plot mean test score
plt.rcdefaults()
y = [test_score_comparison[i] for i in test_score_comparison]
x = [i for i in test_score_comparison]

ax3.barh(x, y, align='center')
ax3.invert_yaxis()
ax3.set_xlabel('Mean Fit Time')
ax3.set_title('Time to Fit The Model (most accurate of each model)') 

plt.subplots_adjust(bottom=0, right=0.8, top=1.2)
                    
plt.show()

# %% [markdown]
# ### Feature Importance for some of the models:

# %% [markdown]
# > Here we see that for random forest the `sepal_width` and `petal_length` are respectively least and most important features in the model

# %%
print(cv_fit[2].best_estimator_)
My_model= cv_fit[2].best_estimator_.fit(X_train, y_train)
sorted(zip(My_model.feature_importances_, X_train.columns), reverse=True)[0:4]
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# [(0.6935899825910002, 'petal_length'),
#  (0.25417682262633656, 'petal_width'),
#  (0.0522331947826631, 'sepal_length'),
#  (0.0, 'sepal_width')]

# %% [markdown]
# # Correlation Map Function Definition

# %%
# this defines the histogram for correlation map
def plot_histograms( df , variables , n_rows , n_cols ):
    fig = plt.figure( figsize = ( 16 , 12 ) )
    for i, var_name in enumerate( variables ):
        ax=fig.add_subplot( n_rows , n_cols , i+1 )
        df[ var_name ].hist( bins=10 , ax=ax )
        ax.set_title( 'Skew: ' + str( round( float( df[ var_name ].skew() ) , ) ) ) # + ' ' + var_name ) #var_name+" Distribution")
        ax.set_xticklabels( [] , visible=False )
        ax.set_yticklabels( [] , visible=False )
    fig.tight_layout()  # Improves appearance a bit.
    plt.show()

def plot_distribution( df , var , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , hue=target , aspect=4 , row = row , col = col )
    facet.map( sns.kdeplot , var , shade= True )
    facet.set( xlim=( 0 , df[ var ].max() ) )
    facet.add_legend()

def plot_categories( df , cat , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , row = row , col = col )
    facet.map( sns.barplot , cat , target )
    facet.add_legend()

def plot_correlation_map( df ):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 5 ,  5) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )

def describe_more( df ):
    var = [] ; l = [] ; t = []
    for x in df:
        var.append( x )
        l.append( len( pd.value_counts( df[ x ] ) ) )
        t.append( df[ x ].dtypes )
    levels = pd.DataFrame( { 'Variable' : var , 'Levels' : l , 'Datatype' : t } )
    levels.sort_values( by = 'Levels' , inplace = True )
    return levels

def plot_variable_importance( X , y ):
    tree = DecisionTreeClassifier( random_state = 99 )
    tree.fit( X , y )
    plot_model_var_imp( tree , X , y )
    
def plot_model_var_imp( model , X , y ):
    imp = pd.DataFrame( 
        model.feature_importances_  , 
        columns = [ 'Importance' ] , 
        index = X.columns 
    )
    imp = imp.sort_values( [ 'Importance' ] , ascending = True )
    imp[ : 10 ].plot( kind = 'barh' )
    print (model.score( X , y ))

    
# Correlation Map
plot_correlation_map( df.drop('species', axis=1) )

# %%
# a simple double check
for i in range(len(models)):
    print(fit_model_list[i][0],fit_model_list[i][1] )
# Out:
# Gradient Boosting Classifier ({'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50},)
# Logistic Regression ({'C': 100},)
# Random Forest Classifier ({'max_depth': 2, 'n_estimators': 5},)
# Support Vector Classifier ({'C': 10, 'kernel': 'linear'},)
# KNN ({'leaf_size': 10, 'n_neighbors': 3},)
# Decision Tree Classifier ({'max_depth': 3},)
# Neural Network Classifier ({'activation': 'tanh', 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'max_iter': 500, 'tol': 0.005},)
# Gaussian Naive Bayes ({},)
# Linear Discriminant Analysis ({},)

# %%
# Here is the whole optimized models defined 
for i in range(len(models)):
#     print(fit_model_list[i][0],fit_model_list[i][2][0] )
    print(fit_model_list[i][2][0] ,'\n\n')
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.01, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=50,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
#
#
# LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
# ...

# %% [markdown]
# # Metrics
# ***
#  - **Accuracy**
#
#         1. Predicted correctly/ total number of examples ((tp+tn)/total)
#         2. Overall, how often is the classifier correct?
#         3. Sum of diagonals on the total
#
#
#
#  - **Precision**
#          1. When it predicts yes, how often is it correct? ((tp + fp) / predicted yes)
#          2. Individual diagonal cell devided by the sum of the columns
#
#  - **Recall (aka True Positive Rate or Sensitivity)**
#         1. Predicted surviving that really survived / Total number that really survived
#         2. When it's actually yes, how often does it predict yes? (tp/actual yes)
#         3. Individual diagonal cell devided by the sum of its row

# %% [markdown]
# # precision_score (averaged)

# %%
y_val_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_val )))
for i in range(len(models)):
    y_pred = fit_model_list[i][2][0].predict(X_val)
    y_pred

    y_pred_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_pred )))
    y_pred_new

    print(
         '{:30}'.format(fit_model_list[i][0]),
        'precision',round(precision_score(y_val_new, y_pred_new,average='micro'),3),
         )
# Out:
# Gradient Boosting Classifier   precision 0.867
# Logistic Regression            precision 0.9
# Random Forest Classifier       precision 0.867
# Support Vector Classifier      precision 0.933
# KNN                            precision 0.967
# Decision Tree Classifier       precision 0.867
# Neural Network Classifier      precision 0.9
# Gaussian Naive Bayes           precision 0.867
# Linear Discriminant Analysis   precision 0.967

# %% [markdown]
# # precision_score

# %%
y_val_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_val )))
for i in range(len(models)):
    y_pred = fit_model_list[i][2][0].predict(X_val)
    y_pred

    y_pred_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_pred )))
    y_pred_new

    print(
         '{:30}'.format(fit_model_list[i][0]),
        'precision',precision_score(y_val_new, y_pred_new,average=None),
         )
# Out:
# Gradient Boosting Classifier   precision [0.9 0.8 1. ]
# Logistic Regression            precision [0.90909091 0.85714286 1.        ]
# Random Forest Classifier       precision [0.9 0.8 1. ]
# Support Vector Classifier      precision [0.85714286 1.         1.        ]
# KNN                            precision [1.         0.92857143 1.        ]
# Decision Tree Classifier       precision [0.9 0.8 1. ]
# Neural Network Classifier      precision [0.8 1.  1. ]
# Gaussian Naive Bayes           precision [0.9 0.8 1. ]
# Linear Discriminant Analysis   precision [1.         0.92857143 1.        ]

# %% [markdown]
# # accuracy_score

# %%
y_val_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_val )))
for i in range(len(models)):
    y_pred = fit_model_list[i][2][0].predict(X_val)
    y_pred

    y_pred_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_pred )))
    y_pred_new

    print(
         '{:30}'.format(fit_model_list[i][0]),
        'accuracy_score', round(accuracy_score(y_val_new, y_pred_new),3),
         )
# Out:
# Gradient Boosting Classifier   accuracy_score 0.867
# Logistic Regression            accuracy_score 0.9
# Random Forest Classifier       accuracy_score 0.867
# Support Vector Classifier      accuracy_score 0.933
# KNN                            accuracy_score 0.967
# Decision Tree Classifier       accuracy_score 0.867
# Neural Network Classifier      accuracy_score 0.9
# Gaussian Naive Bayes           accuracy_score 0.867
# Linear Discriminant Analysis   accuracy_score 0.967

# %% [markdown]
# # recall_score

# %%
y_val_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_val )))
for i in range(len(models)):
    y_pred = fit_model_list[i][2][0].predict(X_val)
    y_pred

    y_pred_new = np.array(list(map(lambda b: 0 if b=='virginica' else (1 if b =='versicolor' else 2),y_pred )))
    y_pred_new

    print(
         '{:30}'.format(fit_model_list[i][0]),
        'recall_score', recall_score(y_val_new, y_pred_new,average=None)
         )
# Out:
# Gradient Boosting Classifier   recall_score [0.75       0.92307692 1.        ]
# Logistic Regression            recall_score [0.83333333 0.92307692 1.        ]
# Random Forest Classifier       recall_score [0.75       0.92307692 1.        ]
# Support Vector Classifier      recall_score [1.         0.84615385 1.        ]
# KNN                            recall_score [0.91666667 1.         1.        ]
# Decision Tree Classifier       recall_score [0.75       0.92307692 1.        ]
# Neural Network Classifier      recall_score [1.         0.76923077 1.        ]
# Gaussian Naive Bayes           recall_score [0.75       0.92307692 1.        ]
# Linear Discriminant Analysis   recall_score [0.91666667 1.         1.        ]

# %% [markdown]
# # Classification Report

# %%
for i in range(len(models)-1):
    name = fit_model_list[i][0]
    # fit
    print(name)
    model = fit_model_list[i][2][0];
#     print(model)
    model.fit(X_train,y_train)
    predictions = model.predict(X_val)
    print(classification_report(y_val, predictions),'\n')
# Out:
# Gradient Boosting Classifier
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         5
#   versicolor       0.86      0.92      0.89        13
#    virginica       0.91      0.83      0.87        12
#
#    micro avg       0.90      0.90      0.90        30
#    macro avg       0.92      0.92      0.92        30
# weighted avg       0.90      0.90      0.90        30
#
#
# Logistic Regression
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         5
#   versicolor       0.86      0.92      0.89        13
#    virginica       0.91      0.83      0.87        12
#
#    micro avg       0.90      0.90      0.90        30
#    macro avg       0.92      0.92      0.92        30
# weighted avg       0.90      0.90      0.90        30
#
#
# Random Forest Classifier
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         5
# ...

# %% [markdown]
# # Confusion Matrix for all Models

# %%
print(y_val.value_counts(),'\n\n')

for i in range(len(models)):
    name = fit_model_list[i][0]
    # fit
    print(name)
    model = fit_model_list[i][2][0];
#     print(model)
    model.fit(X_train,y_train)
    predictions = model.predict(X_val)
    print(confusion_matrix(y_val, predictions),'\n')
# Out:
# versicolor    13
# virginica     12
# setosa         5
# Name: species, dtype: int64
#
#
# Gradient Boosting Classifier
# [[ 5  0  0]
#  [ 0 12  1]
#  [ 0  2 10]]
#
# Logistic Regression
# [[ 5  0  0]
#  [ 0 12  1]
#  [ 0  2 10]]
#
# Random Forest Classifier
# [[ 5  0  0]
#  [ 0 12  1]
#  [ 0  3  9]]
#
# Support Vector Classifier
# [[ 5  0  0]
#  [ 0 11  2]
#  [ 0  0 12]]
#
# KNN
# [[ 5  0  0]
#  [ 0 13  0]
#  [ 0  1 11]]
#
# Decision Tree Classifier
# [[ 5  0  0]
#  [ 0 12  1]
#  [ 0  2 10]]
#
# Neural Network Classifier
# [[ 5  0  0]
#  [ 0 11  2]
#  [ 0  0 12]]
#
# Gaussian Naive Bayes
# [[ 5  0  0]
#  [ 0 12  1]
#  [ 0  3  9]]
#
# Linear Discriminant Analysis
# [[ 5  0  0]
#  [ 0 13  0]
#  [ 0  1 11]]

# %% [markdown]
# ### Creating a numpy array of species names

# %%
class_names =  list(set(df['species']))
class_names
# ['virginica', 'versicolor', 'setosa']

# creat a numpy array of the different labels name
class_names = np.array(class_names, dtype='<U10')
class_names = np.array(['setosa','versicolor','virginica'])

# %% [markdown]
# ### Confusion Matrix Plots for all Models

# %%
normalize=False
title=None
cmap=plt.cm.gist_yarg
# Compute confusion matrix

            
num_each = int(np.ceil(len(models)/2.0))


fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(20, 20))
ii = 0
for row in ax:
    for my_ax in row:
        
        model = fit_model_list[ii][2][0]
        model_name = fit_model_list[ii][0]
        # fit
        y_pred = model.fit(X_train,y_train).predict(X_val)

        y_pred_new = np.array(list(map(lambda b: 2 if b=='virginica' else (1 if b =='versicolor' else 0),y_pred )))
        y_val_new = np.array(list(map(lambda b: 2 if b=='virginica' else (1 if b =='versicolor' else 0),y_val )))


        cm = confusion_matrix(y_val_new, y_pred_new)
        # Only use the labels that appear in the data

  
        classes = class_names[unique_labels(y_val_new, y_pred_new)]
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

 
        
        im = my_ax.imshow(cm, interpolation='nearest', cmap=cmap)
        my_ax.figure.colorbar(im, ax=my_ax)
        # We want to show all ticks...
        my_ax.set(xticks=np.arange(cm.shape[1]),
            yticks=np.arange(cm.shape[0]),
            # ... and label them with the respective list entries
            xticklabels=classes, yticklabels=classes,
            title=model_name,
            # title=title,
            ylabel='True label',
            xlabel='Predicted label')



        # Rotate the tick labels and set their alignment.
        plt.setp(my_ax.get_xticklabels(), rotation=45, ha="right",
                rotation_mode="anchor")

        # Loop over data dimensions and create text annotations.
        fmt = '.2f' if normalize else 'd'
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                my_ax.text(j, i, format(cm[i, j], fmt),
                        ha="center", va="center",
                        color="white" if cm[i, j] > thresh else "black")
        ii+=1
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Normalized Confusion Matrix Plots for all Models

# %% [markdown]
# Just change the normalized=True on above plot
